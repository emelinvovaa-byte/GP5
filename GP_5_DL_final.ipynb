# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект №5. Deep Learning

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 25.05.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 03.06.2026
#
# __Дедлайн по загрузке работ:__ 4:00 15.06.2026
#
# __Защита проекта:__ ~

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в систему [Anytask](https://anytask.org/), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/16IB8mURLGKoipq0Jld6wOGPMpJbRQ8GCkSZKbIP-XYA/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (то есть, например, для автоматической генерации кода по одному из этапов) **одному из участников команды** необходимо предварительно загрузить работу в систему [Anytask](https://anytask.org/). Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub.*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(25052026)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современной бизнес-индустрии использование глубинного обучения приобретает критическое значение. Компании активно внедряют нейронные сети для решения самых разных задач: от анализа структурированных табличных данных до работы с изображениями и текстами. Это позволяет бизнесу принимать более обоснованные решения и оперативно реагировать на изменения рынка.
#
# В данном проекте вы на реальных данных попрактикуетесь в построении и сравнении нейросетевых архитектур для решения двух бизнес-задач разной природы. Первая задача будет связана с табличными данными и решается с помощью полносвязных нейронных сетей. Вторая - с неструктурированными данными: изображениями или текстами, - и решается с помощью более сложных архитектур глубинного обучения. Помимо этого, вы получите опыт организации работы над ML-проектом так, как это принято в индустрии: с версионированием кода, воспроизводимыми экспериментами и сохранением всех артефактов.
#
# Принципиально важно, что обе бизнес-задачи должны быть **содержательно связаны между собой** и **относиться к одной и той же компании или платформе** — таким образом, чтобы вместе они образовывали единое и логически целостное решение для выбранного бизнес-контекста. Проект, в котором две задачи решаются для разных компаний или никак не связаны между собой, оценивается в **0 баллов** для всех участников команды.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже вашему вниманию предлагаются примерные этапы реализации проекта:
#
# - Выбор компании и/или платформы;
# - Формулировка двух связанных бизнес-задач, которые могла бы хотеть решить компания/платформа на основе данных: одна на табличных данных, другая на неструктурированных (изображения или текст);
# - Обоснование сформулированных бизнес-задач и описание того, как предлагаемое решение вписывается в бизнес-процессы компании;
# - Получение необходимых данных путём поиска открытых источников/датасетов, парсинга/работы с API;
# - Формулировка задач в терминах глубинного обучения для решения поставленных бизнес-задач;
# - Выбор и обоснование архитектур нейронных сетей для каждой из задач;
# - Первичная обработка данных;
# - Построение, обучение и сравнение нейросетевых архитектур с обязательным логированием экспериментов;
# - Получение и агрегация результатов, финальные выводы.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию и защитить её перед комиссией, а также предоставить ссылку на репозиторий GitHub с кодом.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта, вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных; дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных; и главное, безусловно, — дата-сайентистов: реализовать поставленные задачи с помощью методов глубинного обучения и извлечь полезные инсайты из проделанной работы. А в конце, конечно, презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10-балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задач и бизнес-обоснование (до 2 баллов)
#
# Данный критерий оценивает, насколько обоснованными и осмысленными и **содержательно связанными** получились две решаемые в проекте бизнес-задачи; насколько полно был осуществлён переход от бизнес-задач к задачам глубинного обучения (насколько в реальности постановка задач соответствует исходной постановке задачи с точки зрения интересов компании); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.
#
# По данному критерию можно получить **максимальный балл** только при условии, что в презентации представлена схема, иллюстрирующая, как предлагаемое решение вписывается в бизнес-процессы компании: откуда поступают данные, каким образом они обрабатываются, как модель генерирует предсказания и каким образом эти предсказания используются для принятия бизнес-решений. Строгая нотация не обязательна — важна логика и понятность схемы для стороннего наблюдателя.

# %% [markdown]
# ### Критерий 2. Инструменты извлечения и обработки данных (до 1,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных ручным и автоматизированным образом, использованные средства предобработки, подготовки данных и EDA. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.

# %% [markdown]
# ### Критерий 3. Глубинное обучение на табличных данных (до 2 баллов)
#
# Данный критерий оценивает применение полносвязных нейронных сетей для решения бизнес-задачи на табличных данных. В рамках этого критерия будет рассматриваться корректность постановки задачи, осмысленность выбора архитектуры, качество предобработки данных, а также глубина сравнительного анализа различных конфигураций сети.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии корректного применения полносвязной нейронной сети для решения поставленной задачи на табличных данных.*
#
# *По данному критерию можно получить **1 балл и выше** только при условии осуществления сравнительного анализа различных конфигураций и сложности архитектуры: должно быть рассмотрено не менее трёх вариантов, значимо отличающихся друг от друга — например, по глубине сети, размеру скрытых слоёв, функциям активации, наличию регуляризации. Использование каждой конфигурации, как и подбор гиперпараметров, должны быть подробно описаны и обоснованы; в рамках сравнения должны быть получены и сформулированы явные, значимые выводы о том, как изменение архитектуры влияет на качество решения задачи.*
#
# *По данному критерию можно получить **максимальный балл в 2 балла** только при условии корректного и обоснованного применения архитектурных решений или подходов, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 2 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых конфигураций залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 4. Глубинное обучение на неструктурированных данных  (до 3 баллов)
#
# Данный критерий оценивает применение методов глубинного обучения для решения бизнес-задачи на неструктурированных данных: изображениях или текстах. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным. Кроме того, будет оценен сравнительный анализ архитектур нейронных сетей, использованных в решении.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии использования в проекте сверточных нейронных сетей, рекуррентных нейронных сетей или же более сложных архитектур глубоких нейронных сетей.*
#
# *По данному критерию можно получить **2 балла** только при условии осуществления сравнительного анализа эффективности различных архитектур нейронных сетей внутри вашего проекта на одних и тех же данных. Самих архитектур должно быть не менее трёх; они должны значимо и осмысленно друг от друга отличаться; их использование, как и настройка гиперпараметров, должны быть подробно описаны и обоснованы. Кроме того, в рамках сравнительного анализа должны быть получены и сформулированы явные, значимые выводы о сравнительной эффективности той или иной архитектуры.*
#
# *По данному критерию можно получить **максимальный балл в 3 балла** только при условии корректного и обоснованного применения инструментов/подходов/библиотек для построения моделей, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 3 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых архитектур залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества в разрезе эпох, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 5. Инструменты промышленной разработки (до 1,5 баллов)
#
# Данный критерий оценивает, насколько грамотно и профессионально команда организовала процесс совместной разработки и обеспечила воспроизводимость своих экспериментов. В рамках этого критерия рассматриваются две составляющие: оформление репозитория GitHub и логирование экспериментов.
#
# *По данному критерию можно получить **0,5 балла** при выполнении всех следующих требований к репозиторию GitHub:*
#
# - наличие файла `README.md` с описанием проекта, используемых данных и структуры репозитория — после прочтения этого файла у стороннего человека не должно остаться вопросов о том, что делает проект и как в нём разобраться;
# - наличие файла `.gitignore`;
# - осмысленная структура репозитория: код организован по директориям, понятно, где лежат данные, где модели, где ноутбуки;
# - коммиты делаются осмысленно и регулярно по ходу работы над проектом, с понятными комментариями — по истории репозитория должно быть видно, что команда работала совместно на протяжении всего времени, а не залила всё в одном коммите накануне дедлайна.
#
# *По данному критерию можно получить **1 балл** при дополнительном выполнении следующего условия: все эксперименты с моделями — как на табличных, так и на неструктурированных данных — залогированы с использованием специализированного инструмента логирования экспериментов (например, MLflow, Weights & Biases, ClearML, DagsHub или аналогичного). Каждый эксперимент должен быть зафиксирован отдельным запуском и содержать: параметры модели и обучения, метрики качества — для табличных задач в целом по выборке, для задач на неструктурированных данных дополнительно в разрезе эпох, — а также артефакт обученной модели, позволяющий воспроизвести её предсказания без повторного обучения. Хранение файлов моделей исключительно напрямую в репозитории без привязки к системе логирования не засчитывается.*
#
# *По данному критерию можно получить **1,5 балла** при дополнительном выполнении следующего условия: в системе логирования сохранены также данные, использованные при обучении и валидации моделей, — таким образом, чтобы любой эксперимент можно было полностью воспроизвести, имея доступ только к системе логирования, без необходимости искать данные отдельно.*

# %%
import json
import pandas as pd
import os
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dfs = []
for category in os.listdir('drive/MyDrive/data'):
    if category != '.DS_Store':
        df_ = pd.read_json(f'drive/MyDrive/data/{category}/{category}.json')
        df_['category'] = category
        dfs.append(df_)
df = pd.concat(dfs)

# %%
df['is_original'] = df['descr'].str.lower().str.contains('оригинал').astype(int)

# %%
df = df.drop(['src', 'img_name', 'descr'], axis=1)
df['Размер'] = df['Размер'].str.replace(',', '.').astype(np.float32)
df_dummies = pd.get_dummies(df, dtype=int)

# %%
pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.27.2)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.50)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.62.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.5.20)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)

# %%
import wandb

wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: elesinegor (elesinegor-hse) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_dummies.drop('price', axis=1), df['price'], train_size=0.8, random_state=100)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

y_mean, y_std = y_train.mean(), y_train.std()
y_train = (y_train - y_mean) / y_std
y_test = (y_test - y_mean) / y_std

# %%
from torch.utils.data import Dataset, DataLoader
import torch
from torch import nn

class AvitoDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(
            X,
            dtype=torch.float32
        )
        self.y = torch.tensor(
            y,
            dtype=torch.float32
        )

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = AvitoDataset(X_train, y_train.values)
test_dataset   = AvitoDataset(X_test, y_test.values)

BATCH_SIZE = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
)

# %%
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

def train_one_epoch(model, train_dataloader, val_dataloader, loss_function, optimizer, scheduler,
                    epoch, n_epochs, device="cuda:0"):
    model.train()

    train_loss, train_loss_unscaled, eval_loss_unscaled = 0.0, 0.0, 0.0

    for features, targets in train_dataloader:
        optimizer.zero_grad()
        features = features.to(device)
        targets = targets.to(device)

        preds = model(features)
        loss = loss_function(preds, targets)
        with torch.no_grad():
            unscaled_loss = loss_function(preds * y_std + y_mean, targets * y_std + y_mean)
        loss.backward()
        optimizer.step()
        scheduler.step()

        train_loss += loss.item() * len(features)
        train_loss_unscaled += unscaled_loss.item() * len(features)

    print('Train loss', train_loss / len(train_dataloader.dataset))
    print('Train loss (unscaled)', np.sqrt(train_loss_unscaled / len(train_dataloader.dataset)))

    model.eval()

    for features, targets in val_dataloader:
        features = features.to(device)
        targets = targets.to(device)

        with torch.no_grad():
            preds = model(features)
            unscaled_loss = loss_function(preds * y_std + y_mean, targets * y_std + y_mean)

        eval_loss_unscaled += unscaled_loss.item() * len(features)

    print('Eval loss (unscaled)', np.sqrt(eval_loss_unscaled / len(val_dataloader.dataset)))

    print('----------------')

    wandb.log({
        "epoch":      epoch,
        "train/loss": train_loss / len(train_dataloader.dataset),
        "train/loss_unscaled": np.sqrt(train_loss_unscaled / len(train_dataloader.dataset)),
        "val/loss_unscaled":   np.sqrt(eval_loss_unscaled / len(val_dataloader.dataset)),
    })

def train(model, train_dataloader, val_dataloader, loss_function, optimizer, scheduler, device="cuda:0", n_epochs=10):
    model.to(device)
    for epoch in range(n_epochs):
        train_one_epoch(model, train_dataloader, val_dataloader, loss_function, optimizer, scheduler,
                        epoch, n_epochs, device)

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Linear(253, 253),
            nn.ReLU(),
            nn.Linear(253, 32),
            nn.ReLU(),
            nn.Linear(32, 5),
            nn.ReLU(),
            nn.Linear(5, 1),
        )

    def forward(self, x):
        return self.sequential(x)

# %% [markdown]
# Для начала пробуем архитектуру из 4 слоёв с батчсайзом 32. Eval loss получился 6679.08

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Linear(253, 253),
            nn.ReLU(),
            nn.Linear(253, 142),
            nn.ReLU(),
            nn.Linear(142, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 5),
            nn.ReLU(),
            nn.Linear(5, 1),
        )

    def forward(self, x):
        return self.sequential(x)

# %% [markdown]
# Попробуем добавить несколько слоёв и сделаем обучение более глубоким. Eval loss стал 6676.85

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Linear(253, 253),
            nn.Dropout(0.3),
            nn.ReLU(),
            nn.Linear(253, 142),
            nn.BatchNorm1d(142),
            nn.ReLU(),
            nn.Linear(142, 64),
            nn.ReLU(),
            nn.Linear(64, 5),
            nn.ReLU(),
            nn.Linear(5, 1),
        )

    def forward(self, x):
        return self.sequential(x)

# %% [markdown]
# В середине обучения модель на эвал лос показывает лучше результат, чем в конце. Добавим дропаут и батчнорм, чтобы избавиться от переобучения.
# Eval loss стал 6677.04, в дропауте нет необходимости

# %% [markdown]
# Вывод:
# Лучшаая архитектура №2

# %%
model = Model()
loss_fn = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.999)

# %%
EXP_NAME = "arch_3_lr_1e4_bs_32_is_original_dropout"

# %%
run = wandb.init(
    project="test-project",
    config={
        "epochs": 10,
        "model":  model,
    },
    name=EXP_NAME
)

wandb.watch(model, log="all", log_freq=10)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train/loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_unscaled</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss_unscaled</td><td>█▃▃▃▃▂▂▂▂▂▁▂▂▂▁▂▂▂▂▁▂▂▂▂▂▁▂▂▁▂▂▂▁▂▁▂▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>62</td></tr><tr><td>train/loss</td><td>1.00024</td></tr><tr><td>train/loss_unscaled</td><td>6227.65219</td></tr><tr><td>val/loss_unscaled</td><td>6683.75226</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch_3_lr_1e4_bs_32_is_original_no_dropout</strong> at: <a href='https://wandb.ai/elesinegor-hse/test-project/runs/dnw9b8gt' target="_blank">https://wandb.ai/elesinegor-hse/test-project/runs/dnw9b8gt</a><br> View project at: <a href='https://wandb.ai/elesinegor-hse/test-project' target="_blank">https://wandb.ai/elesinegor-hse/test-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_094651-dnw9b8gt/logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260616_095008-sj0o0zky</code>
# Syncing run <strong><a href='https://wandb.ai/elesinegor-hse/test-project/runs/sj0o0zky' target="_blank">arch_3_lr_1e4_bs_32_is_original_dropout</a></strong> to <a href='https://wandb.ai/elesinegor-hse/test-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/elesinegor-hse/test-project' target="_blank">https://wandb.ai/elesinegor-hse/test-project</a>
#  View run at <a href='https://wandb.ai/elesinegor-hse/test-project/runs/sj0o0zky' target="_blank">https://wandb.ai/elesinegor-hse/test-project/runs/sj0o0zky</a>

# %%
train(model, train_loader, test_loader, loss_fn, optimizer, scheduler, 'cpu', 100)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([15])) that is different to the input size (torch.Size([15, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Train loss 1.0051823236644568
# Train loss (unscaled) 6243.029177913641
# Eval loss (unscaled) 6678.640015906604
# ----------------
# Train loss 1.0007009702195448
# Train loss (unscaled) 6229.097226848513
# Eval loss (unscaled) 6677.853075652384
# ----------------
# Train loss 1.0006051373573397
# Train loss (unscaled) 6228.799032638048
# Eval loss (unscaled) 6677.356151124898
# ----------------
# Train loss 1.0003502732130762
# Train loss (unscaled) 6228.005456583727
# Eval loss (unscaled) 6676.992157582169
# ----------------
# Train loss 1.0002150060819095
# Train loss (unscaled) 6227.584353285086
# Eval loss (unscaled) 6677.004123176766
# ----------------
# Train loss 1.0002733328091822
# Train loss (unscaled) 6227.7659284892625
# Eval loss (unscaled) 6677.156142874138
# ----------------
# Train loss 0.9999628642206991
# Train loss (unscaled) 6226.799401685797
# Eval loss (unscaled) 6677.12896747366
# ----------------
# Train loss 1.0002993663625996
# Train loss (unscaled) 6227.846966965638
# Eval loss (unscaled) 6677.273916784462
# ----------------
# Train loss 0.9999817548546406
# Train loss (unscaled) 6226.8582222511895
# Eval loss (unscaled) 6677.099231487161
# ----------------
# Train loss 1.0000135259568168
# Train loss (unscaled) 6226.95721198121
# Eval loss (unscaled) 6677.120278603833
# ----------------
# Train loss 0.9998877199281305
# Train loss (unscaled) 6226.565530722184
# Eval loss (unscaled) 6677.0097245749885
# ----------------
# Train loss 0.9999231772187078
# Train loss (unscaled) 6226.676016726147
# Eval loss (unscaled) 6676.962750563597
# ----------------
# Train loss 1.0001295374719503
# Train loss (unscaled) 6227.31834211272
# Eval loss (unscaled) 6677.030996796698
# ----------------
# Train loss 1.0001892842237832
# Train loss (unscaled) 6227.504353700257
# Eval loss (unscaled) 6677.174206066584
# ----------------
# Train loss 1.0000231915171898
# Train loss (unscaled) 6226.987253565827
# Eval loss (unscaled) 6677.104043696251
# ----------------
# Train loss 1.0000372518666056
# Train loss (unscaled) 6227.031035334297
# Eval loss (unscaled) 6676.989629514463
# ----------------
# Train loss 0.9999619071299719
# Train loss (unscaled) 6226.796400078676
# Eval loss (unscaled) 6677.033025538958
# ----------------
# Train loss 0.9998846483917513
# Train loss (unscaled) 6226.555882386988
# Eval loss (unscaled) 6677.004386819676
# ----------------
# Train loss 1.0000464588613547
# Train loss (unscaled) 6227.059727498585
# Eval loss (unscaled) 6677.043595560201
# ----------------
# Train loss 1.0001657295199642
# Train loss (unscaled) 6227.431028716119
# Eval loss (unscaled) 6676.934968671035
# ----------------
# Train loss 0.9997150302875452
# Train loss (unscaled) 6226.027641417456
# Eval loss (unscaled) 6676.971354941747
# ----------------
# Train loss 1.000142215625713
# Train loss (unscaled) 6227.3577877457155
# Eval loss (unscaled) 6677.065150250494
# ----------------
# Train loss 1.0001573629429978
# Train loss (unscaled) 6227.404922308236
# Eval loss (unscaled) 6676.97444370121
# ----------------
# Train loss 0.9997079619723741
# Train loss (unscaled) 6226.005786615106
# Eval loss (unscaled) 6677.072203813774
# ----------------
# Train loss 1.0001096869700428
# Train loss (unscaled) 6227.256582872545
# Eval loss (unscaled) 6677.052863369428
# ----------------
# Train loss 0.9999186763699703
# Train loss (unscaled) 6226.661830658873
# Eval loss (unscaled) 6677.01710174622
# ----------------
# Train loss 1.0001999721507058
# Train loss (unscaled) 6227.537665371194
# Eval loss (unscaled) 6677.169270481816
# ----------------
# Train loss 1.0002214706612997
# Train loss (unscaled) 6227.604514556583
# Eval loss (unscaled) 6677.001549236435
# ----------------
# Train loss 0.9999441521523036
# Train loss (unscaled) 6226.741299861791
# Eval loss (unscaled) 6676.89419815331
# ----------------
# Train loss 0.9999587604036481
# Train loss (unscaled) 6226.786572125383
# Eval loss (unscaled) 6676.964301788375
# ----------------
# Train loss 1.000214875793642
# Train loss (unscaled) 6227.584085631649
# Eval loss (unscaled) 6677.00174582822
# ----------------
# Train loss 0.9996896987396301
# Train loss (unscaled) 6225.948846245719
# Eval loss (unscaled) 6677.076966378517
# ----------------
# Train loss 1.0001048893742837
# Train loss (unscaled) 6227.241613687913
# Eval loss (unscaled) 6677.228362902142
# ----------------
# Train loss 0.9996317269529209
# Train loss (unscaled) 6225.768366952408
# Eval loss (unscaled) 6676.980184477714
# ----------------
# Train loss 0.9998746872288705
# Train loss (unscaled) 6226.524945554671
# Eval loss (unscaled) 6677.020966176355
# ----------------
# Train loss 0.9999571223337086
# Train loss (unscaled) 6226.7815352925145
# Eval loss (unscaled) 6676.971680903417
# ----------------
# Train loss 1.0000787082460527
# Train loss (unscaled) 6227.160020596487
# Eval loss (unscaled) 6676.914298149078
# ----------------
# Train loss 0.9999278349032911
# Train loss (unscaled) 6226.690357867529
# Eval loss (unscaled) 6677.075978782687
# ----------------
# Train loss 0.9999010055906078
# Train loss (unscaled) 6226.606806574634
# Eval loss (unscaled) 6677.103954525512
# ----------------
# Train loss 1.0004130076627173
# Train loss (unscaled) 6228.200799510469
# Eval loss (unscaled) 6676.962899729773
# ----------------
# Train loss 0.9999955091424707
# Train loss (unscaled) 6226.901103140308
# Eval loss (unscaled) 6677.077218829127
# ----------------
# Train loss 1.0000094751942379
# Train loss (unscaled) 6226.944556774891
# Eval loss (unscaled) 6676.961518931149
# ----------------
# Train loss 0.9999742694439979
# Train loss (unscaled) 6226.834923743587
# Eval loss (unscaled) 6677.007304105669
# ----------------
# Train loss 0.9999637981695525
# Train loss (unscaled) 6226.80226234009
# Eval loss (unscaled) 6677.012259262733
# ----------------
# Train loss 1.0001610509108017
# Train loss (unscaled) 6227.416397125476
# Eval loss (unscaled) 6676.9230440961055
# ----------------
# Train loss 0.9996536528007243
# Train loss (unscaled) 6225.836497645599
# Eval loss (unscaled) 6676.968770229549
# ----------------
# Train loss 1.0001360960213732
# Train loss (unscaled) 6227.338671773401
# Eval loss (unscaled) 6676.960642439766
# ----------------
# Train loss 0.9998399545225128
# Train loss (unscaled) 6226.4167953335
# Eval loss (unscaled) 6677.052942986769
# ----------------
# Train loss 1.000019470888456
# Train loss (unscaled) 6226.975622148849
# Eval loss (unscaled) 6677.014652014655
# ----------------
# Train loss 0.9995803243642155
# Train loss (unscaled) 6225.608206399518
# Eval loss (unscaled) 6676.93388904074
# ----------------
# Train loss 0.9999837926585606
# Train loss (unscaled) 6226.864409681868
# Eval loss (unscaled) 6677.0805262497015
# ----------------
# Train loss 0.9999821805152285
# Train loss (unscaled) 6226.859650444766
# Eval loss (unscaled) 6676.912618661516
# ----------------
# Train loss 1.0001642868438831
# Train loss (unscaled) 6227.426483287974
# Eval loss (unscaled) 6676.991088117806
# ----------------
# Train loss 0.9997845196633148
# Train loss (unscaled) 6226.244130508956
# Eval loss (unscaled) 6677.002683168135
# ----------------
# Train loss 1.0000940929423257
# Train loss (unscaled) 6227.207982365787
# Eval loss (unscaled) 6677.041435043469
# ----------------
# Train loss 1.0001464151161843
# Train loss (unscaled) 6227.370922841202
# Eval loss (unscaled) 6676.981109942481
# ----------------
# Train loss 1.000176139626631
# Train loss (unscaled) 6227.463408375711
# Eval loss (unscaled) 6676.912029394715
# ----------------
# Train loss 1.0001156260254764
# Train loss (unscaled) 6227.27497902505
# Eval loss (unscaled) 6677.053489635101
# ----------------
# Train loss 1.0000440771144805
# Train loss (unscaled) 6227.052212732349
# Eval loss (unscaled) 6676.920133056737
# ----------------
# Train loss 0.9998297994593159
# Train loss (unscaled) 6226.385136966107
# Eval loss (unscaled) 6676.8844557646935
# ----------------
# Train loss 0.9999650848812885
# Train loss (unscaled) 6226.806336815093
# Eval loss (unscaled) 6677.018067316006
# ----------------
# Train loss 0.9999717034550469
# Train loss (unscaled) 6226.82692668898
# Eval loss (unscaled) 6676.924301557989
# ----------------
# Train loss 0.9998426716793438
# Train loss (unscaled) 6226.425185111292
# Eval loss (unscaled) 6677.04616518068
# ----------------
# Train loss 1.000104865447631
# Train loss (unscaled) 6227.241526184342
# Eval loss (unscaled) 6676.930335805175
# ----------------
# Train loss 0.9998852720135912
# Train loss (unscaled) 6226.557876600809
# Eval loss (unscaled) 6677.050386021605
# ----------------
# Train loss 0.999786502211528
# Train loss (unscaled) 6226.250292233487
# Eval loss (unscaled) 6677.032904864531
# ----------------
# Train loss 0.9999953240888492
# Train loss (unscaled) 6226.90043274192
# Eval loss (unscaled) 6677.141354229953
# ----------------
# Train loss 1.0001598410195944
# Train loss (unscaled) 6227.4127012637355
# Eval loss (unscaled) 6676.967597386685
# ----------------
# Train loss 0.9998138582788677
# Train loss (unscaled) 6226.335599421467
# Eval loss (unscaled) 6676.9908161252315
# ----------------
# Train loss 0.9996606900437944
# Train loss (unscaled) 6225.858490483572
# Eval loss (unscaled) 6676.9636462491935
# ----------------
# Train loss 0.9996101266137998
# Train loss (unscaled) 6225.701182468745
# Eval loss (unscaled) 6676.891439884282
# ----------------
# Train loss 0.9999095598057197
# Train loss (unscaled) 6226.6334617275315
# Eval loss (unscaled) 6677.172599546752
# ----------------
# Train loss 0.9998664864297313
# Train loss (unscaled) 6226.49935488429
# Eval loss (unscaled) 6676.926540612501
# ----------------
# Train loss 0.9995517764550453
# Train loss (unscaled) 6225.519414162169
# Eval loss (unscaled) 6677.023724908315
# ----------------
# Train loss 0.9998153893448084
# Train loss (unscaled) 6226.3401206974
# Eval loss (unscaled) 6676.916831323705
# ----------------
# Train loss 1.0002708065773602
# Train loss (unscaled) 6227.758140878078
# Eval loss (unscaled) 6676.901200510557
# ----------------
# Train loss 1.0001387983209393
# Train loss (unscaled) 6227.347175836414
# Eval loss (unscaled) 6677.001327769412
# ----------------
# Train loss 1.000247981940506
# Train loss (unscaled) 6227.687045045261
# Eval loss (unscaled) 6676.914640898076
# ----------------
# Train loss 1.0000984585821362
# Train loss (unscaled) 6227.221692286678
# Eval loss (unscaled) 6677.010944664717
# ----------------
# Train loss 0.9998606800570504
# Train loss (unscaled) 6226.481304359574
# Eval loss (unscaled) 6676.914316655114
# ----------------
# Train loss 0.9998574321820555
# Train loss (unscaled) 6226.47128904654
# Eval loss (unscaled) 6676.9955739279085
# ----------------
# Train loss 0.9999139412053445
# Train loss (unscaled) 6226.647068139112
# Eval loss (unscaled) 6677.013892073502
# ----------------
# Train loss 0.9998265416509273
# Train loss (unscaled) 6226.374957637146
# Eval loss (unscaled) 6677.093197650826
# ----------------
# Train loss 1.0002063783631103
# Train loss (unscaled) 6227.557563436921
# Eval loss (unscaled) 6677.200560338779
# ----------------
# Train loss 0.9998079327900428
# Train loss (unscaled) 6226.316981459748
# Eval loss (unscaled) 6676.932284270646
# ----------------
# Train loss 0.9999814533711097
# Train loss (unscaled) 6226.857365784893
# Eval loss (unscaled) 6676.972129089927
# ----------------
# Train loss 0.9999099653125888
# Train loss (unscaled) 6226.6346958975055
# Eval loss (unscaled) 6676.9673182490205
# ----------------
# Train loss 0.9998853158798346
# Train loss (unscaled) 6226.557957675123
# Eval loss (unscaled) 6676.973004546917
# ----------------
# Train loss 1.0000995428916075
# Train loss (unscaled) 6227.224973518683
# Eval loss (unscaled) 6677.141391326839
# ----------------
# Train loss 1.0004393489115162
# Train loss (unscaled) 6228.282825779209
# Eval loss (unscaled) 6677.096713358301
# ----------------
# Train loss 0.9998681614442296
# Train loss (unscaled) 6226.5046214588965
# Eval loss (unscaled) 6676.950745042541
# ----------------
# Train loss 0.9994141974506887
# Train loss (unscaled) 6225.090926943469
# Eval loss (unscaled) 6676.902548096805
# ----------------
# Train loss 0.9999362766134583
# Train loss (unscaled) 6226.716637833443
# Eval loss (unscaled) 6677.039695164662
# ----------------
# Train loss 0.9998115581382809
# Train loss (unscaled) 6226.328393960221
# Eval loss (unscaled) 6676.902710691985
# ----------------
# Train loss 0.9999919466236437
# Train loss (unscaled) 6226.8899229137705
# Eval loss (unscaled) 6677.029417613656
# ----------------
# Train loss 0.9995741530950941
# Train loss (unscaled) 6225.589050882186
# Eval loss (unscaled) 6676.946682773324
# ----------------
# Train loss 0.9999613580835296
# Train loss (unscaled) 6226.794720539398
# Eval loss (unscaled) 6677.041164946552
# ----------------
# Train loss 0.999886004673645
# Train loss (unscaled) 6226.560153212371
# Eval loss (unscaled) 6677.089118770245
# ----------------
# Train loss 0.9998619673929692
# Train loss (unscaled) 6226.485286519457
# Eval loss (unscaled) 6676.990578906383
# ----------------
# Train loss 1.0000373676755439
# Train loss (unscaled) 6227.031406394741
# Eval loss (unscaled) 6677.04103953826
# ----------------

# %%
MODEL_PATH = f"{EXP_NAME}.pth"

torch.save(
    {
        "model_state": model.state_dict(),
        "optim_state": optimizer.state_dict(),
    },
    MODEL_PATH
)

# %%
artifact = wandb.Artifact(
    name=EXP_NAME,
    type="model",
    description=EXP_NAME,
)

artifact.add_file(MODEL_PATH)
run.log_artifact(artifact)
# Out:
# <Artifact arch_2_lr_1e4_bs_32_is_original_no_dropout>

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>train/loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_unscaled</td><td>█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss_unscaled</td><td>▆▇▂▁▁█▇█████████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train/loss</td><td>0.9997</td></tr><tr><td>train/loss_unscaled</td><td>6225.98364</td></tr><tr><td>val/loss_unscaled</td><td>6676.85868</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">arch_2_lr_1e4_bs_32_is_original_no_dropout</strong> at: <a href='https://wandb.ai/elesinegor-hse/test-project/runs/7j8rnstj' target="_blank">https://wandb.ai/elesinegor-hse/test-project/runs/7j8rnstj</a><br> View project at: <a href='https://wandb.ai/elesinegor-hse/test-project' target="_blank">https://wandb.ai/elesinegor-hse/test-project</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260616_093900-7j8rnstj/logs</code>
